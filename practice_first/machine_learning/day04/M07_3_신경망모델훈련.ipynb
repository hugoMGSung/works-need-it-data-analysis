# %% [markdown]
# ### 사전준비

# %%
# 기본 패키지 import
import numpy as np
import pandas as pd
import scipy as sp

import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# 한글 설정/차트 마이너스 깨짐현상 해결 / seaborn 화면설정
from matplotlib import rc
import matplotlib.font_manager as fm

plt.rc('font', family='Malgun Gothic')
sns.set(font='Malgun Gothic', rc={'axes.unicode_minus':False}, style='darkgrid')

# %%
# 머신러닝 패키지 import
import statsmodels.api as sm # 안쓸껄??
import sklearn as sk

# %%
# 실행마다 동일한 결과를 얻기 위해 케라스에 랜덤 시드를 사용하고 텐서플로 연산을 결정적으로 만듭니다. 
import tensorflow as tf

tf.keras.utils.set_random_seed(42)
tf.config.experimental.enable_op_determinism()

# %% [markdown]
# ### 신경망 모델 훈련
#
# #### 손실 곡선

# %%
from tensorflow import keras
from sklearn.model_selection import train_test_split
from keras.datasets.fashion_mnist import load_data

(train_input, train_target), (test_input, test_target) = load_data()

train_scaled = train_input / 255.0

train_scaled, val_scaled, train_target, val_target = train_test_split(
    train_scaled, train_target, test_size=0.2, random_state=42)

# %%
def model_fn(a_layer=None):
    model = keras.Sequential()
    model.add(keras.layers.Flatten(input_shape=(28, 28)))
    model.add(keras.layers.Dense(100, activation='relu'))
    if a_layer:
        model.add(a_layer)
    model.add(keras.layers.Dense(10, activation='softmax'))
    return model

# %%
model = model_fn()

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 784)               0
#
#  dense (Dense)               (None, 100)               78500
#
#  dense_1 (Dense)             (None, 10)                1010
#
# =================================================================
# Total params: 79,510
# Trainable params: 79,510
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='sparse_categorical_crossentropy', metrics='accuracy')

history = model.fit(train_scaled, train_target, epochs=5, verbose=0)

# %%
print(history.history.keys())
# Out:
# dict_keys(['loss', 'accuracy'])

# %%
plt.figure(figsize=(10,5))
plt.plot(history.history['loss'])
plt.xlabel('epoch')
plt.ylabel('loss')
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.plot(history.history['accuracy'])
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.show()

# %%
model = model_fn()
model.compile(loss='sparse_categorical_crossentropy', metrics='accuracy')

history = model.fit(train_scaled, train_target, epochs=20, verbose=0)

# %%
plt.figure(figsize=(10,5))
plt.plot(history.history['loss'])
plt.xlabel('epoch')
plt.ylabel('loss')
plt.show()

# %% [markdown]
# #### 검증손실

# %%
model = model_fn()
model.compile(loss='sparse_categorical_crossentropy', metrics='accuracy')

history = model.fit(train_scaled, train_target, epochs=20, verbose=1, 
                    validation_data=(val_scaled, val_target))
# Out:
# Epoch 1/20
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.5307 - accuracy: 0.8120 - val_loss: 0.4258 - val_accuracy: 0.8513
# Epoch 2/20
# 1500/1500 [==============================] - 2s 2ms/step - loss: 0.3940 - accuracy: 0.8576 - val_loss: 0.4344 - val_accuracy: 0.8429
# Epoch 3/20
# 1500/1500 [==============================] - 2s 2ms/step - loss: 0.3533 - accuracy: 0.8730 - val_loss: 0.3675 - val_accuracy: 0.8682
# Epoch 4/20
# 1500/1500 [==============================] - 2s 2ms/step - loss: 0.3306 - accuracy: 0.8821 - val_loss: 0.3741 - val_accuracy: 0.8711
# Epoch 5/20
# 1500/1500 [==============================] - 2s 2ms/step - loss: 0.3159 - accuracy: 0.8869 - val_loss: 0.3777 - val_accuracy: 0.8677
# Epoch 6/20
# 1500/1500 [==============================] - 2s 2ms/step - loss: 0.3076 - accuracy: 0.8924 - val_loss: 0.3580 - val_accuracy: 0.8790
# Epoch 7/20
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.2956 - accuracy: 0.8947 - val_loss: 0.3739 - val_accuracy: 0.8722
# Epoch 8/20
# 1500/1500 [==============================] - 2s 2ms/step - loss: 0.2889 - accuracy: 0.8964 - val_loss: 0.3685 - val_accuracy: 0.8805
# Epoch 9/20
# 1500/1500 [==============================] - 2s 2ms/step - loss: 0.2829 - accuracy: 0.9004 - val_loss: 0.3719 - val_accuracy: 0.8826
# Epoch 10/20
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.2772 - accuracy: 0.9034 - val_loss: 0.3909 - val_accuracy: 0.8819
# Epoch 11/20
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.2721 - accuracy: 0.9057 - val_loss: 0.3739 - val_accuracy: 0.8818
# Epoch 12/20
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.2643 - accuracy: 0.9087 - val_loss: 0.4057 - val_accuracy: 0.8766
# Epoch 13/20
# 1500/1500 [==============================] - 2s 2ms/step - loss: 0.2592 - accuracy: 0.9101 - val_loss: 0.4021 - val_accuracy: 0.8850
# Epoch 14/20
# 1500/1500 [==============================] - 2s 2ms/step - loss: 0.2547 - accuracy: 0.9097 - val_loss: 0.3999 - val_accuracy: 0.8828
# Epoch 15/20
# 1500/1500 [==============================] - 2s 2ms/step - loss: 0.2532 - accuracy: 0.9133 - val_loss: 0.4173 - val_accuracy: 0.8799
# Epoch 16/20
# 1500/1500 [==============================] - 2s 2ms/step - loss: 0.2497 - accuracy: 0.9150 - val_loss: 0.4327 - val_accuracy: 0.8756
# Epoch 17/20
# 1500/1500 [==============================] - 2s 2ms/step - loss: 0.2426 - accuracy: 0.9171 - val_loss: 0.4214 - val_accuracy: 0.8874
# Epoch 18/20
# 1500/1500 [==============================] - 2s 2ms/step - loss: 0.2398 - accuracy: 0.9182 - val_loss: 0.4110 - val_accuracy: 0.8838
# Epoch 19/20
# 1500/1500 [==============================] - 2s 2ms/step - loss: 0.2335 - accuracy: 0.9203 - val_loss: 0.4556 - val_accuracy: 0.8743
# Epoch 20/20
# 1500/1500 [==============================] - 2s 2ms/step - loss: 0.2334 - accuracy: 0.9218 - val_loss: 0.4361 - val_accuracy: 0.8861

# %%
print(history.history.keys())
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
plt.figure(figsize=(10,5))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['train', 'val'])
plt.show()

# %%
model = model_fn()
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', 
              metrics='accuracy')

history = model.fit(train_scaled, train_target, epochs=20, verbose=0, 
                    validation_data=(val_scaled, val_target))

# %%
plt.figure(figsize=(10,5))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['train', 'val'])
plt.show()

# %% [markdown]
# ### 드롭아웃
#
# 제프리 힌턴의 제안, 랜덤 뉴런의 출력을 0으로 만들어 과대적합 막기

# %%
model = model_fn(keras.layers.Dropout(0.3))

model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_4 (Flatten)         (None, 784)               0
#
#  dense_8 (Dense)             (None, 100)               78500
#
#  dropout (Dropout)           (None, 100)               0
#
#  dense_9 (Dense)             (None, 10)                1010
#
# =================================================================
# Total params: 79,510
# Trainable params: 79,510
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', 
              metrics='accuracy')

history = model.fit(train_scaled, train_target, epochs=20, verbose=0, 
                    validation_data=(val_scaled, val_target))

# %%
plt.figure(figsize=(10,5))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['train', 'val'])
plt.show()

# %% [markdown]
# ### 모델 저장과 복원

# %%
model = model_fn(keras.layers.Dropout(0.3))
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', 
              metrics='accuracy')

history = model.fit(train_scaled, train_target, epochs=10, verbose=0, 
                    validation_data=(val_scaled, val_target))

# %%
model.save_weights('model-weights.h5')

# %%
model.save('model-whole.h5')

# %%
model = model_fn(keras.layers.Dropout(0.3))

model.load_weights('model-weights.h5')

# %%
import numpy as np

val_labels = np.argmax(model.predict(val_scaled), axis=-1)
print(np.mean(val_labels == val_target))
# Out:
# 375/375 [==============================] - 0s 851us/step
# 0.8825

# %%
model = keras.models.load_model('model-whole.h5')

model.evaluate(val_scaled, val_target)
# Out:
# 375/375 [==============================] - 0s 936us/step - loss: 0.3332 - accuracy: 0.8825
# [0.3332017660140991, 0.8824999928474426]

# %% [markdown]
# ### 콜백

# %%
model = model_fn(keras.layers.Dropout(0.3))
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', 
              metrics='accuracy')

checkpoint_cb = keras.callbacks.ModelCheckpoint('best-model.h5', 
                                                save_best_only=True)

model.fit(train_scaled, train_target, epochs=20, verbose=0, 
          validation_data=(val_scaled, val_target),
          callbacks=[checkpoint_cb])

# %%
model = keras.models.load_model('best-model.h5')

model.evaluate(val_scaled, val_target)
# Out:
# 375/375 [==============================] - 0s 929us/step - loss: 0.3172 - accuracy: 0.8888
# [0.31720471382141113, 0.8887500166893005]

# %%
model = model_fn(keras.layers.Dropout(0.3))
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', 
              metrics='accuracy')

checkpoint_cb = keras.callbacks.ModelCheckpoint('best-model.h5', 
                                                save_best_only=True)
early_stopping_cb = keras.callbacks.EarlyStopping(patience=2,
                                                  restore_best_weights=True)

history = model.fit(train_scaled, train_target, epochs=20, verbose=0, 
                    validation_data=(val_scaled, val_target),
                    callbacks=[checkpoint_cb, early_stopping_cb])

# %%
print(early_stopping_cb.stopped_epoch)
# Out:
# 9

# %%
plt.figure(figsize=(10,5))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['train', 'val'])
plt.show()

# %%
model.evaluate(val_scaled, val_target)
# Out:
# 375/375 [==============================] - 0s 936us/step - loss: 0.3329 - accuracy: 0.8807
# [0.332854688167572, 0.8806666731834412]
