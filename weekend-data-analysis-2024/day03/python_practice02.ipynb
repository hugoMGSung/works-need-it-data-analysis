# %% [markdown]
# ### 크롤링 속도향상
#
# - re(Regular Expression: 정규표현식), requests 모듈 네트워크 크롤링 기본
# - thread, concurrent.futures 모듈 사용 속도 개선

# %%
# 모듈 임포트
import requests
import re
import time

# 스레드
import threading
# 비동기처리 고수준 인테페이스 모듈
from concurrent.futures import ThreadPoolExecutor

# %% [markdown]
# #### 크롤링 예제 사이트
# - https://search.daum.net/search?w=img&nil_search=btn&DA=NTB&enc=utf8&q=%EA%B3%A0%EC%96%91%EC%9D%B4

# %% [markdown]
# #### 이미지 저장함수

# %%
# 이미지 저장함수
def save_image(idx, img_url):
    res = requests.get(img_url).content # 이미지 바이트값 

    with open(f'./img/{idx}.jpg', mode='wb') as f:
        f.write(res)
        print(f'saved image with {idx}')

# %%
# 이미지 저장 테스트
save_image(9999, 'https://th.bing.com/th/id/OIP.Y9h80DtXEhUNVqMCm8cn8wHaEJ?w=333&h=187&c=7&r=0&o=5&dpr=1.3&pid=1.7')
# Out:
# saved image with 9999

# %% [markdown]
# #### 다음 고양이 이미지 검색URL 추출 후 저장
#
# - 다음은 Beautifulsoup 같은 모듈로 DOM 추출이 조금 힘듬
# - 그래서 정규식으로 추출 진행

# %%
reg = re.compile('oimgurl: ".{0,300}", cpid')  # oimgurl: *** , cpid 사이에 들어있는 문자열을 추출

url = 'https://search.daum.net/search?w=img&nil_search=btn&DA=NTB&enc=utf8&q=%EA%B3%A0%EC%96%91%EC%9D%B4' # 검색결과 웹 페이지
html = requests.get(url) # 정적으로 URL 요청
html_raw_data = str(html.content)

html_raw_data
# Out:
# 'b\'<!doctype html>\\n<html xmlns="http://www.w3.org/1999/xhtml" lang="ko">\\n<head profile="http://a9.com/-/spec/opensearch/1.1/">\\n<meta http-equiv="content-Type" content="text/html;charset=utf-8" />\\n<meta http-equiv="X-UA-Compatible" content="IE=edge" />\\n<meta name="autocomplete" content="off" />\\n<meta name="referrer" content="always">\\n<meta name="format-detection" content="telephone=no" />\\n<meta property="og:title" content="\\xea\\xb3\\xa0\\xec\\x96\\x91\\xec\\x9d\\xb4 &ndash; Daum \\xea\\xb2\\x80\\xec\\x83\\x89" />\\n<meta property="og:url" content="https://search.daum.net/search?w=img&amp;nil_search=btn&amp;DA=NTB&amp;enc=utf8&amp;q=%EA%B3%A0%EC%96%91%EC%9D%B4" />\\n<meta property="og:description" content="Daum \\xea\\xb2\\x80\\xec\\x83\\x89\\xec\\x97\\x90\\xec\\x84\\x9c \\xea\\xb3\\xa0\\xec\\x96\\x91\\xec\\x9d\\xb4\\xec\\x97\\x90 \\xeb\\x8c\\x80\\xed\\x95\\x9c \\xec\\xb5\\x9c\\xec\\x8b\\xa0\\xec\\xa0\\x95\\xeb\\xb3\\xb4\\xeb\\xa5\\xbc \\xec\\xb0\\xbe\\xec\\x95\\x84\\xeb\\xb3\\xb4\\xec\\x84\\xb8\\xec\\x9a\\x94." />\\n<meta property="og:image" content="https://search1.daumcdn.net/search/statics/common/img/og_search_20240403.png" />\\n<meta property="og:site_name" content="\\xeb\\x8b\\xa4\\xec\\x9d\\x8c\\xea\\xb2\\x80\\xec\\x83\\x89" />\\n<title>\\xea\\xb3\\xa0\\xec\\x96\\x91\\xec\\x9d\\xb4 &ndash; Daum \\xea\\xb2\\x80\\xec\\x83\\x89</title>\\n<link rel="search" type="application/opensearchdescription+xml" href="//search.daum.net/OpenSearch.xml" title="Daum">\\n<link rel="stylesheet" type="text/css" href=\\\'//search1.daumcdn.net/search/statics/common/css/2024/p_common.1118041417.css\\\' charset="utf-8">\\n<link rel="stylesheet" type="text/css" href=\\\'//search1.daumcdn.net/search/statics/common/css/2024/p_component.0610023548.css\\\' charset="utf-8">\\n<link rel="stylesheet" type="text/css" href=\\\'//search1.daumcdn.net/search/statics/common/css/2024/pm_common.1126093328.css\\\' charset="utf-8">\\n<link rel="stylesheet" type="text/css" href=\\\'//search1.daumcdn.net/search/statics/common/js/fe/cubic/20241125111553/cubic.css\\\' charset="utf-8">\\n<link rel="stylesheet" type="text/css" href=\\\'//search1.daumcdn.net/search/statics/common/css/2024/p_collection.1028014646.css\\\' charset="utf-8">\\n<link rel="stylesheet" type="text/css" href=\\\'//search1.daumcdn.net/search/statics/common/css/2024/p_collection2.0923031103.css\\\' charset="utf-8">\\n<script type="text/javascript">\\nvar uk = "062e4418-8702-49f1-acce-48d3ea8496b3";\\nvar mk = "062e4418-8702-49f1-acce-48d3ea8496b3";\\nvar ksk = "062e4418-8702-49f1-acce-48d3ea8496b3";\\nvar ud = "";\\nvar uuid = "";\\nvar adid = "";\\nvar adid_enabled = "N";\\nvar viewio = "i";\\nvar viewsite = "";\\nvar ServerTime = "20241130140317";\\nvar utf8Query = encodeURIComponent("\\xea\\xb3\\xa0\\xec\\x96\\x91\\xec\\x9d\\xb4");\\nvar topQuery = "\\xea\\xb3\\xa0\\xec\\x96\\x91\\xec\\x9d\\xb4";\\nvar backQuery = encodeURIComponent("\\xea\\xb3\\xa0\\xec\\x96\\x91\\xec\\x9d\\xb4");\\nvar login_yn = "N";\\nvar encodeType = "2";\\nvar refCode = "";\\nvar bucketType = "";\\nvar name_check = "0";\\nvar mobileDevice = "N";\\nvar param_w = "img";\\nvar param_da = "NTB";\\nvar paramCfg = "";\\nvar param_cnucc = ""; \\nvar tpl_cfg = ""; \\nvar cnucc = "";\\nvar usrIp = "210.119.12.52";\\nvar isDetailTab = "N"; \\nvar schSort = "";\\nvar existMobileTabYn = "N"; \\nvar width_over_620 = "N";\\nvar sPageLoadedmsTime =  164 ;\\nvar isReleaseMode = \\\'\\\';\\nvar isTotDebugMode = false;\\nvar KAKAO_ACCOUNT_ID_CONNECTED = "N";\\nvar displayInfo = {"SER":[{"code":"IIM","doc_count":80}],"SGR":[{"code":"NSJ","doc_count":0},{"code":"DCC","doc_count":0}],"SUI":[],"CUT":[]};\\nvar usr4 = "NSJ0_DCC0_IIM80";\\nvar slCallType = "sync";\\nvar pageLoadedTime = 0;\\nvar startTime = new Date().getTime();\\nvar sugLocCode = "";\\nvar searchLog = {\\nuc: 0,\\nclickCount: 0,\\ndl: ""\\n};\\nvar SEARCHLOGDOMAIN = "\\\\/\\\\/sl.search.daum.net"; \\nvar CNUCC_URL = "https:\\\\/\\\\/harm.search.daum.net\\\\/v2\ ...

# %%
reg_iter = reg.finditer(html_raw_data)

for idx, data in enumerate(reg_iter):
#  https://blog.kakaocdn.net/dn/521pA/btr0ObzuAtM/ryZ9Ro63r5peoxXW4uLiY1/img.jpg
#  https://t1.daumcdn.net/cfile/tistory/163C23254CB588CD39
#  https://t1.daumcdn.net/cfile/tistory/163C23254CB588CD39
#  https://blog.kakaocdn.net/dn/cRyafY/btsrSLhZeNg/MkYPV6vi7ndYGuQxXQfMQ1/img.jpg
#  https://blog.kakaocdn.net/dn/cRyafY/btsrSLhZeNg/MkYPV6vi7ndYGuQxXQfMQ1/img.jpg
#  https://blog.kakaocdn.net/dn/empH8U/btsq8IzE3Xy/y4jWd5qcvL9y1ZtFEoeflK/img.jpg
#  https://blog.kakaocdn.net/dn/empH8U/btsq8IzE3Xy/y4jWd5qcvL9y1ZtFEoeflK/img.jpg
#  https://blog.kakaocdn.net/dn/efg31p/btstaAGrGf2/2OuAsG0iIpybklJdHdJTfk/img.jpg
#  https://blog.kakaocdn.net/dn/efg31p/btstaAGrGf2/2OuAsG0iIpybklJdHdJTfk/img.jpg
#  https://blog.kakaocdn.net/dn/c0QRNK/btsEZCrG2Py/ux5a6OK1bKRpRiyGB6idI1/img.png
#  https://blog.kakaocdn.net/dn/c0QRNK/btsEZCrG2Py/ux5a6OK1bKRpRiyGB6idI1/img.png
#  https://blog.kakaocdn.net/dn/6XdwF/btsDkwAdlqY/CFKVImgv6kpSlGWmF8ZzFk/img.png
#  https://blog.kakaocdn.net/dn/6XdwF/btsDkwAdlqY/CFKVImgv6kpSlGWmF8ZzFk/img.png
#  http://dbscthumb.phinf.naver.net/2741_000_1/20130924143045049_WT806XTTN.jpg/ia15_9_i1.jpg?type=w107_fst_n&wm=Y
#  http://dbscthumb.phinf.naver.net/2741_000_1/20130924143045049_WT806XTTN.jpg/ia15_9_i1.jpg?type=w107_fst_n&wm=Y
#  https://search.pstatic.net/sunny/?src=http%3A%2F%2Fimagescdn.gettyimagesbank.com%2F500%2F15%2F106%2F601%2F0%2F480010984.jpg&type=b400
#  https://search.pstatic.net/sunny/?src=http%3A%2F%2Fimagescdn.gettyimagesbank.com%2F500%2F15%2F106%2F601%2F0%2F480010984.jpg&type=b400
#  https://blog.kakaocdn.net/dn/EC10a/btsGlxi9D3C/KMGr9xQsZpjrZnCY1OFK5K/img.jpg
#  https://blog.kakaocdn.net/dn/EC10a/btsGlxi9D3C/KMGr9xQsZpjrZnCY1OFK5K/img.jpg

# %% [markdown]
# #### 일반 이미지 저장시간 측정

# %%
start_time = time.time()    # 시작시간 체크

reg_iter = reg.finditer(html_raw_data)

for idx, data in enumerate(reg_iter):
    img_url = data.group().split('oimgurl:')[1].replace(', cpid', '').replace('"', '') # 필요없는 요소 제거하고 URL만 남기는 처리
    # print(img_url)
    save_image(idx, img_url)

end_time = time.time()     # 종료시간 체크
print(f'저장 소요시간 => {end_time - start_time} 초.')
# Out:
# saved image with 0
# saved image with 1
# saved image with 2
# saved image with 3
# saved image with 4
# saved image with 5
# saved image with 6
# saved image with 7
# saved image with 8
# saved image with 9
# saved image with 10
# saved image with 11
# saved image with 12
# saved image with 13
# saved image with 14
# saved image with 15
# saved image with 16
# saved image with 17
# saved image with 18
# saved image with 19
# saved image with 20
# saved image with 21
# saved image with 22
# saved image with 23
# saved image with 24
# saved image with 25
# saved image with 26
# saved image with 27
# saved image with 28
# saved image with 29
# saved image with 30
# saved image with 31
# saved image with 32
# saved image with 33
# saved image with 34
# saved image with 35
# saved image with 36
# saved image with 37
# saved image with 38
# saved image with 39
# saved image with 40
# saved image with 41
# saved image with 42
# saved image with 43
# saved image with 44
# saved image with 45
# saved image with 46
# saved image with 47
# saved image with 48
# saved image with 49
# saved image with 50
# saved image with 51
# saved image with 52
# saved image with 53
# saved image with 54
# saved image with 55
# saved image with 56
# saved image with 57
# saved image with 58
# saved image with 59
# saved image with 60
# saved image with 61
# saved image with 62
# saved image with 63
# saved image with 64
# saved image with 65
# saved image with 66
# saved image with 67
# saved image with 68
# saved image with 69
# saved image with 70
# saved image with 71
# saved image with 72
# saved image with 73
# saved image with 74
# saved image with 75
# saved image with 76
# saved image with 77
# saved image with 78
# saved image with 79
# saved image with 80
# saved image with 81
# saved image with 82
# saved image with 83
# saved image with 84
# saved image with 85
# saved image with 86
# saved image with 87
# saved image with 88
# saved image with 89
# saved image with 90
# saved image with 91
# saved image with 92
# saved image with 93
# saved image with 94
# saved image with 95
# saved image with 96
# saved image with 97
# saved image with 98
# saved image with 99
# saved image with 100
# saved image with 101
# saved image with 102
# saved image with 103
# saved image with 104
# saved image with 105
# saved image with 106
# saved image with 107
# saved image with 108
# saved image with 109
# saved image with 110
# saved image with 111
# saved image with 112
# saved image with 113
# saved image with 114
# saved image with 115
# saved image with 116
# saved image with 117
# saved image with 118
# saved image with 119
# saved image with 120
# saved image with 121
# saved image with 122
# saved image with 123
# saved image with 124
# saved image with 125
# saved image with 126
# saved image with 127
# saved image with 128
# saved image with 129
# saved image with 130
# saved image with 131
# saved image with 132
# saved image with 133
# saved image with 134
# saved image with 135
# saved image with 136
# saved image with 137
# saved image with 138
# saved image with 139
# saved image with 140
# saved image with 141
# saved image with 142
# saved image with 143
# saved image with 144
# saved image with 145
# saved image with 146
# saved image with 147
# saved image with 148
# saved image with 149
# saved image with 150
# saved image with 151
# saved image with 152
# saved image with 153
# saved image with 154
# saved image with 155
# saved image with 156
# saved image with 157
# saved image with 158
# saved image with 159
# 저장 소요시간 => 81.76077246665955 초.

# %% [markdown]
# ##### 일반 저장방식으로 81.76초 소요

# %% [markdown]
# #### 스레드 방식으로 저장
#
# - 기존 소스 그대로 활용

# %%
start_time = time.time()    # 시작시간 체크

reg_iter = reg.finditer(html_raw_data)
thred_list = []   # 1. thread 처리를 위한 리스트 

for idx, data in enumerate(reg_iter):
    img_url = data.group().split('oimgurl:')[1].replace(', cpid', '').replace('"', '') # 필요없는 요소 제거하고 URL만 남기는 처리
    # 2. 스레드 처리할 스레드 변수 선언, target에 기존 사용하던 함수입력, args에 기존 함수에 사용하던 매개변수 갯수만큼 튜플로 입력
    worker = threading.Thread(target=save_image, args=(idx, img_url))
    worker.start()   # 3. 스레드 시작
    thred_list.append(worker)  # 4. 리스트 추가

for thread in thred_list:  # 5. 스레드 종료
    thread.join()   

end_time = time.time()     # 종료시간 체크
print(f'저장 소요시간 => {end_time - start_time} 초.')
# Out:
# saved image with 0
# saved image with 1
# saved image with 16
# saved image with 17
# saved image with 28
# saved image with 29
# saved image with 9saved image with 8
#
# saved image with 5
# saved image with 25
# saved image with 2
# saved image with 24
# saved image with 11
# saved image with 3
# saved image with 4
# saved image with 20
# saved image with 7saved image with 10
# saved image with 19
#
# saved image with 14
# saved image with 21
# saved image with 12
# saved image with 50
# saved image with 51
# saved image with 52
# saved image with 53
# saved image with 6
# saved image with 18
# saved image with 15
# saved image with 13
# saved image with 26
# saved image with 32
# saved image with 27
# saved image with 56
# saved image with 33
# saved image with 57
# saved image with 58
# saved image with 59
# saved image with 60
# saved image with 61
# saved image with 34
# saved image with 37
# saved image with 23
# saved image with 22
# saved image with 35
# saved image with 36
# saved image with 41
# saved image with 69
# saved image with 68
# saved image with 40
# saved image with 43
# saved image with 30
# saved image with 42
# saved image with 45
# saved image with 44
# saved image with 31
# saved image with 82
# saved image with 83
# saved image with 38
# saved image with 48
# saved image with 39
# saved image with 49
# saved image with 66
# saved image with 67
# saved image with 74
# saved image with 75
# saved image with 76
# saved image with 77
# saved image with 54
# saved image with 84
# saved image with 85
# saved image with 46
# saved image with 90
# saved image with 91
# saved image with 65
# saved image with 47
# saved image with 64
# saved image with 92
# saved image with 55
# saved image with 93
# saved image with 98
# saved image with 62
# saved image with 99
# saved image with 73
# saved image with 72
# saved image with 63
# saved image with 70
# saved image with 100
# saved image with 71
# saved image with 80
# saved image with 79
# saved image with 78
# saved image with 101
# saved image with 89
# saved image with 108
# saved image with 106
# saved image with 88
# saved image with 114
# saved image with 109
# saved image with 115
# saved image with 130
# saved image with 131
# saved image with 86
# saved image with 107
# saved image with 81
# saved image with 94
# saved image with 122
# saved image with 123
# saved image with 116
# saved image with 96
# saved image with 117
# saved image with 97
# saved image with 104
# saved image with 95
# saved image with 105
# saved image with 87
# saved image with 103
# saved image with 102
# saved image with 125
# saved image with 124
# saved image with 138
# saved image with 139
# saved image with 154
# saved image with 133
# saved image with 110
# saved image with 132
# saved image with 155
# saved image with 118
# saved image with 140
# saved image with 112
# saved image with 113
# saved image with 111
# saved image with 141
# saved image with 120
# saved image with 119
# saved image with 126
# saved image with 128
# saved image with 149
# saved image with 148
# saved image with 127
# saved image with 121
# saved image with 134
# saved image with 137
# saved image with 147
# saved image with 129
# saved image with 136
# saved image with 142
# saved image with 143
# saved image with 135
# saved image with 157
# saved image with 156
# saved image with 144
# saved image with 146
# saved image with 150
# saved image with 145
# saved image with 152
# saved image with 158
# saved image with 159
# saved image with 151
# saved image with 153
# 저장 소요시간 => 13.03464651107788 초.

# %% [markdown]
# ##### 스레드 저장방식으로 13초 소요

# %% [markdown]
# #### concurrent.futures 모듈 사용 병렬처리

# %%
start_time = time.time()    # 시작시간 체크

reg_iter = reg.finditer(html_raw_data)

# concurrent.futures에 ThreadPoolExecutor에 포함시키면 됨
with ThreadPoolExecutor(max_workers=16) as executor:
    for idx, data in enumerate(reg_iter):
        img_url = data.group().split('oimgurl:')[1].replace(', cpid', '').replace('"', '') # 필요없는 요소 제거하고 URL만 남기는 처리
        # print(img_url)
        executor.submit(save_image, idx, img_url)

end_time = time.time()     # 종료시간 체크
print(f'저장 소요시간 => {end_time - start_time} 초.')
# Out:
# saved image with 0saved image with 1
#
# saved image with 16
# saved image with 17
# saved image with 14
# saved image with 6
# saved image with 5
# saved image with 19
# saved image with 2
# saved image with 15
# saved image with 10
# saved image with 9
# saved image with 7
# saved image with 11
# saved image with 8
# saved image with 3
# saved image with 18
# saved image with 28
# saved image with 29
# saved image with 4
# saved image with 13
# saved image with 12
# saved image with 20
# saved image with 21
# saved image with 22
# saved image with 23
# saved image with 24
# saved image with 25
# saved image with 36
# saved image with 26
# saved image with 33
# saved image with 30
# saved image with 32
# saved image with 35
# saved image with 27
# saved image with 34
# saved image with 31
# saved image with 50
# saved image with 51
# saved image with 53
# saved image with 52
# saved image with 37
# saved image with 56
# saved image with 57
# saved image with 58
# saved image with 60
# saved image with 59
# saved image with 61
# saved image with 38
# saved image with 39
# saved image with 40
# saved image with 43saved image with 44
#
# saved image with 68
# saved image with 41
# saved image with 69
# saved image with 42
# saved image with 46
# saved image with 47
# saved image with 45
# saved image with 48
# saved image with 55
# saved image with 54
# saved image with 62
# saved image with 63
# saved image with 49
# saved image with 64
# saved image with 82
# saved image with 83
# saved image with 66
# saved image with 65
# saved image with 71
# saved image with 67
# saved image with 72
# saved image with 70
# saved image with 73
# saved image with 75
# saved image with 77
# saved image with 76
# saved image with 74
# saved image with 78
# saved image with 79
# saved image with 85
# saved image with 80
# saved image with 84
# saved image with 81
# saved image with 86
# saved image with 87
# saved image with 90
# saved image with 91
# saved image with 89
# saved image with 88
# saved image with 97
# saved image with 96
# saved image with 93
# saved image with 98
# saved image with 95
# saved image with 92
# saved image with 94
# saved image with 100
# saved image with 99
# saved image with 102
# saved image with 101
# saved image with 103
# saved image with 105
# saved image with 104
# saved image with 111
# saved image with 110
# saved image with 115
# saved image with 106
# saved image with 114
# saved image with 107
# saved image with 109
# saved image with 112
# saved image with 117
# saved image with 108
# saved image with 113
# saved image with 130
# saved image with 131
# saved image with 118
# saved image with 116
# saved image with 119
# saved image with 121
# saved image with 120
# saved image with 122
# saved image with 126
# saved image with 127
# saved image with 123
# saved image with 128
# saved image with 129
# saved image with 137
# saved image with 134
# saved image with 133
# saved image with 136
# saved image with 124
# saved image with 135
# saved image with 132
# saved image with 125
# saved image with 138
# saved image with 154
# saved image with 155
# saved image with 140
# saved image with 139
# saved image with 141saved image with 142
#
# saved image with 143
# saved image with 145
# saved image with 144
# saved image with 148
# saved image with 149
# saved image with 150
# saved image with 157
# saved image with 156
# saved image with 152
# saved image with 146
# saved image with 151
# saved image with 153
# saved image with 158
# saved image with 159
# saved image with 147
# 저장 소요시간 => 13.979562282562256 초.

# %% [markdown]
# ##### concurrent.futures 사용 동시저장 처리시간은 13.98초 소요
