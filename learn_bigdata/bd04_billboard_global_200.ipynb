# %% [markdown]
# ### 빌보드 글로벌 200

# %%
# !pip install lxml

# %%
# !pip install selenium
# Out:
# ...
#   Using cached trio-0.27.0-py3-none-any.whl.metadata (8.6 kB)
# ...
#   Using cached trio_websocket-0.11.1-py3-none-any.whl.metadata (4.7 kB)
# ...
#   Using cached websocket_client-1.8.0-py3-none-any.whl.metadata (8.0 kB)
# ...
#   Using cached attrs-24.2.0-py3-none-any.whl.metadata (11 kB)
# ...
#   Using cached sortedcontainers-2.4.0-py2.py3-none-any.whl.metadata (10 kB)
# ...
#   Using cached outcome-1.3.0.post0-py2.py3-none-any.whl.metadata (2.6 kB)
# ...
#   Using cached sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# ...
#   Using cached cffi-1.17.1-cp311-cp311-win_amd64.whl.metadata (1.6 kB)
# ...
#   Using cached wsproto-1.2.0-py3-none-any.whl.metadata (5.6 kB)
# ...
#   Using cached PySocks-1.7.1-py3-none-any.whl.metadata (13 kB)
# ...
#   Using cached pycparser-2.22-py3-none-any.whl.metadata (943 bytes)
# ...
#   Using cached h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# ...
#    ---------------------------------------- 0.0/9.7 MB ? eta -:--:--
#    ----------- ---------------------------- 2.9/9.7 MB 15.3 MB/s eta 0:00:01
# ...

# %%
from lxml import html
import requests
import time

# %%
url = 'https://www.billboard.com/charts/billboard-global-200/2024-11-01/'

# %%
page = requests.get(url)

# %%
page
# Out:
# <Response [403]>

# %%
# selenium의 webdriver를 사용하기 위한 import
from selenium import webdriver

# selenium으로 키를 조작하기 위한 import
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By

# 페이지 로딩을 기다리는데에 사용할 time 모듈 import
import time

import datetime

# BeautifulSoup 패키지 불러오기
# 주로 bs로 이름을 간단히 만들어서 사용함
from bs4 import BeautifulSoup as bs

# %%
datetime.datetime(2024, 11, 1).strftime(f'%Y-%m-%d')
# Out:
# '2024-11-01'

# %%
(datetime.datetime(2024, 11, 1) + datetime.timedelta(days=-7))
# Out:
# datetime.datetime(2024, 10, 25, 0, 0)

# %%
for i in range(9, -1, -1):
    print(datetime.datetime(2024, 11, 1) + datetime.timedelta(days=-7 * i))
# Out:
# 2024-08-30 00:00:00
# 2024-09-06 00:00:00
# 2024-09-13 00:00:00
# 2024-09-20 00:00:00
# 2024-09-27 00:00:00
# 2024-10-04 00:00:00
# 2024-10-11 00:00:00
# 2024-10-18 00:00:00
# 2024-10-25 00:00:00
# 2024-11-01 00:00:00

# %%
for i in range(9, -1, -1):
    print((datetime.datetime(2024, 11, 1) + datetime.timedelta(days=-7 * i)).strftime(f'%Y-%m-%d'))
# Out:
# 2024-08-30
# 2024-09-06
# 2024-09-13
# 2024-09-20
# 2024-09-27
# 2024-10-04
# 2024-10-11
# 2024-10-18
# 2024-10-25
# 2024-11-01

# %%
sub_url = 'https://www.billboard.com/charts/billboard-global-200/'

# %%
for i in range(9, -1, -1):
    datefmt = ((datetime.datetime(2024, 11, 1) + datetime.timedelta(days=-7 * i)).strftime(f'%Y-%m-%d'))
    last_url = sub_url + datefmt + '/'
    print(last_url)
# Out:
# https://www.billboard.com/charts/billboard-global-200/2024-08-30/
# https://www.billboard.com/charts/billboard-global-200/2024-09-06/
# https://www.billboard.com/charts/billboard-global-200/2024-09-13/
# https://www.billboard.com/charts/billboard-global-200/2024-09-20/
# https://www.billboard.com/charts/billboard-global-200/2024-09-27/
# https://www.billboard.com/charts/billboard-global-200/2024-10-04/
# https://www.billboard.com/charts/billboard-global-200/2024-10-11/
# https://www.billboard.com/charts/billboard-global-200/2024-10-18/
# https://www.billboard.com/charts/billboard-global-200/2024-10-25/
# https://www.billboard.com/charts/billboard-global-200/2024-11-01/

# %%
# 크롬드라이버 실행
driver = webdriver.Chrome() 

#크롬 드라이버에 url 주소 넣고 실행
driver.get(url)

# 페이지가 완전히 로딩되도록 3초동안 기다림
time.sleep(3)

# %%
search_box = driver.find_elements(By.CLASS_NAME, 'o-chart-results-list-row-container')

# %%
len(search_box)
# Out:
# 200

# %%
for i in search_box:
    title = i.text
    print(title)
# Out:
# 1
# NEW
# APT.
# ROSE & Bruno Mars
# -
# 1
# 1
# 2
# Die With A Smile
# Lady Gaga & Bruno Mars
# 1
# 1
# 10
# 3
# Birds Of A Feather
# Billie Eilish
# 2
# 1
# 23
# 4
# Tu Boda
# Oscar Maydon & Fuerza Regida
# 22
# 4
# 4
# 5
# Espresso
# Sabrina Carpenter
# 4
# 1
# 28
# 6
# Mantra
# Jennie
# 3
# 3
# 2
# 7
# Taste
# Sabrina Carpenter
# 5
# 2
# 9
# 8
# NEW
# Love Somebody
# Morgan Wallen
# -
# 8
# 1
# 9
# Beautiful Things
# Benson Boone
# 7
# 1
# 40
# 10
# Good Luck, Babe!
# Chappell Roan
# 6
# 5
# 28
# 11
# A Bar Song (Tipsy)
# Shaboozey
# 8
# 3
# 28
# 12
# Lose Control
# Teddy Swims
# 12
# 4
# 58
# 13
# Si Antes Te Hubiera Conocido
# Karol G
# 9
# 5
# 18
# 14
# Please Please Please
# Sabrina Carpenter
# 11
# 1
# 20
# 15
# Who
# Jimin
# 13
# 1
# 14
# 16
# Timeless
# The Weeknd & Playboi Carti
# 10
# 3
# 4
# 17
# I Love You, I'm Sorry
# Gracie Abrams
# 14
# 14
# 12
# 18
# Night Changes
# One Direction
# 117
# 18
# 4
# 19
# Sailor Song
# Gigi Perez
# 16
# 16
# 9
# 20
# Wildflower
# ...

# %%
for idx, data in enumerate(search_box):
    titles = data.text.split('\n')
    print(f'{titles[0]}, {titles[-5]}, {titles[-4]}')
# Out:
# 1, APT., ROSE & Bruno Mars
# 2, Die With A Smile, Lady Gaga & Bruno Mars
# 3, Birds Of A Feather, Billie Eilish
# 4, Tu Boda, Oscar Maydon & Fuerza Regida
# 5, Espresso, Sabrina Carpenter
# 6, Mantra, Jennie
# 7, Taste, Sabrina Carpenter
# 8, Love Somebody, Morgan Wallen
# 9, Beautiful Things, Benson Boone
# 10, Good Luck, Babe!, Chappell Roan
# 11, A Bar Song (Tipsy), Shaboozey
# 12, Lose Control, Teddy Swims
# 13, Si Antes Te Hubiera Conocido, Karol G
# 14, Please Please Please, Sabrina Carpenter
# 15, Who, Jimin
# 16, Timeless, The Weeknd & Playboi Carti
# 17, I Love You, I'm Sorry, Gracie Abrams
# 18, Night Changes, One Direction
# 19, Sailor Song, Gigi Perez
# 20, Wildflower, Billie Eilish
# 21, I Had Some Help, Post Malone Featuring Morgan Wallen
# 22, Too Sweet, Hozier
# 23, Story Of My Life, One Direction
# 24, Moonlit Floor, LISA
# 25, Bed Chem, Sabrina Carpenter
# 26, The Emptiness Machine, Linkin Park
# 27, El Lokeron, Tito Double P
# ...
